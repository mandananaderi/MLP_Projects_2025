# %% [markdown]
# <a href="https://colab.research.google.com/github/mandananaderi/MLP_Projects_2025/blob/main/RBF_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Initialization

# %%
import keras
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import tensorflow as tf
from keras.layers import Layer
from tensorflow.keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Breast Cancer Data Loading

# %%
cancer = load_breast_cancer()
X = cancer.data
y = cancer.target
label = np.zeros((len(y), 2))
label[np.where(y == 1), 1] = 1  # Wherever y is equal to 1, put the number 1 in column 1
label[np.where(y == 0), 0] = 1  # Wherever y is equal to 0, put the number 1 in column 0

Xtrain, Xtest, y_train, y_test = train_test_split(X, label, test_size = 0.3)
scaler_X = MinMaxScaler().fit(Xtrain)
X_train, X_test = scaler_X.transform(Xtrain), scaler_X.transform(Xtest)

# %% [markdown]
# # Define RBF Layer

# %%
class RBFLayer(Layer):

  def __init__(self, units, gamma, **kwargs):
    super(RBFLayer, self).__init__(**kwargs)
    self.units = units
    self.gamma = K.cast_to_floatx(gamma)


  def build(self, input_shape):
    self.mu = self.add_weight(name='mu',
                              shape= (int(input_shape[1]), self.units),
                              initializer='uniform',
                              trainable= True)
    super(RBFLayer, self).build(input_shape)


  def call(self, inputs):
    diff = K.expand_dims(inputs)- self.mu
    l2 = K.sum(K.pow(diff, 2), axis=1)
    res = K.exp(-1 * self.gamma * l2)
    return res


  def compute_output_shape(self, input_shape):
        return (input_shape[0], self.units)

# %% [markdown]
# # Simple MLP Training

# %%
model = Sequential()
model.add(Dense(50, activation = 'sigmoid'))
model.add(Dense(2, activation = 'sigmoid'))
opt = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)
loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer = opt, loss=loss, metrics =['binary_crossentropy'])
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 100, batch_size = 5)
# Out:
# Epoch 1/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_crossentropy: 0.7685 - loss: 0.7685 - val_binary_crossentropy: 0.6664 - val_loss: 0.6664
# Epoch 2/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.6593 - loss: 0.6593 - val_binary_crossentropy: 0.6535 - val_loss: 0.6535
# Epoch 3/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.6657 - loss: 0.6657 - val_binary_crossentropy: 0.6486 - val_loss: 0.6486
# Epoch 4/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.6363 - loss: 0.6363 - val_binary_crossentropy: 0.6446 - val_loss: 0.6446
# Epoch 5/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.6474 - loss: 0.6474 - val_binary_crossentropy: 0.6404 - val_loss: 0.6404
# Epoch 6/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.6440 - loss: 0.6440 - val_binary_crossentropy: 0.6365 - val_loss: 0.6365
# Epoch 7/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.6162 - loss: 0.6162 - val_binary_crossentropy: 0.6323 - val_loss: 0.6323
# Epoch 8/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.6128 - loss: 0.6128 - val_binary_crossentropy: 0.6282 - val_loss: 0.6282
# Epoch 9/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.6221 - loss: 0.6221 - val_binary_crossentropy: 0.6241 - val_loss: 0.6241
# Epoch 10/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.6113 - loss: 0.6113 - val_binary_crossentropy: 0.6199 - val_loss: 0.6199
# Epoch 11/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.6248 - loss: 0.6248 - val_binary_crossentropy: 0.6156 - val_loss: 0.6156
# Epoch 12/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.6113 - loss: 0.6113 - val_binary_crossentropy: 0.6112 - val_loss: 0.6112
# Epoch 13/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.6048 - loss: 0.6048 - val_binary_crossentropy: 0.6068 - val_loss: 0.6068
# Epoch 14/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.6109 - loss: 0.6109 - val_binary_crossentropy: 0.6022 - val_loss: 0.6022
# Epoch 15/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.6058 - loss: 0.6058 - val_binary_crossentropy: 0.5979 - val_loss: 0.5979
# Epoch 16/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.5892 - loss: 0.5892 - val_binary_crossentropy: 0.5933 - val_loss: 0.5933
# Epoch 17/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.5855 - loss: 0.5855 - val_binary_crossentropy: 0.5885 - val_loss: 0.5885
# Epoch 18/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.5853 - loss: 0.5853 - val_binary_crossentropy: 0.5838 - val_loss: 0.5838
# Epoch 19/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.5594 - loss: 0.5594 - val_binary_crossentropy: 0.5791 - val_loss: 0.5791
# Epoch 20/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.5699 - loss: 0.5699 - val_binary_crossentropy: 0.5742 - val_loss: 0.5742
# Epoch 21/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.5698 - loss: 0.5698 - val_binary_crossentropy: 0.5693 - val_loss: 0.5693
# Epoch 22/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.5754 - loss: 0.5754 - val_binary_crossentropy: 0.5643 - val_loss: 0.5643
# Epoch 23/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.5630 - loss: 0.5630 - val_binary_crossentropy: 0.5592 - val_loss: 0.5592
# Epoch 24/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.5563 - loss: 0.5563 - val_binary_crossentropy: 0.5541 - val_loss: 0.5541
# Epoch 25/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.5448 - loss: 0.5448 - val_binary_crossentropy: 0.5489 - val_loss: 0.5489
# Epoch 26/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.5345 - loss: 0.5345 - val_binary_crossentropy: 0.5438 - val_loss: 0.5438
# Epoch 27/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.5384 - loss: 0.5384 - val_binary_crossentropy: 0.5383 - val_loss: 0.5383
# Epoch 28/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.5244 - loss: 0.5244 - val_binary_crossentropy: 0.5330 - val_loss: 0.5330
# Epoch 29/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.5390 - loss: 0.5390 - val_binary_crossentropy: 0.5275 - val_loss: 0.5275
# Epoch 30/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.5156 - loss: 0.5156 - val_binary_crossentropy: 0.5220 - val_loss: 0.5220
# Epoch 31/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.5079 - loss: 0.5079 - val_binary_crossentropy: 0.5165 - val_loss: 0.5165
# Epoch 32/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.5014 - loss: 0.5014 - val_binary_crossentropy: 0.5111 - val_loss: 0.5111
# Epoch 33/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.5032 - loss: 0.5032 - val_binary_crossentropy: 0.5055 - val_loss: 0.5055
# Epoch 34/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.5119 - loss: 0.5119 - val_binary_crossentropy: 0.4999 - val_loss: 0.4999
# Epoch 35/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.5019 - loss: 0.5019 - val_binary_crossentropy: 0.4943 - val_loss: 0.4943
# Epoch 36/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.4899 - loss: 0.4899 - val_binary_crossentropy: 0.4887 - val_loss: 0.4887
# Epoch 37/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.5031 - loss: 0.5031 - val_binary_crossentropy: 0.4832 - val_loss: 0.4832
# Epoch 38/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.4951 - loss: 0.4951 - val_binary_crossentropy: 0.4776 - val_loss: 0.4776
# Epoch 39/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.4819 - loss: 0.4819 - val_binary_crossentropy: 0.4721 - val_loss: 0.4721
# Epoch 40/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.4521 - loss: 0.4521 - val_binary_crossentropy: 0.4665 - val_loss: 0.4665
# Epoch 41/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.4631 - loss: 0.4631 - val_binary_crossentropy: 0.4610 - val_loss: 0.4610
# Epoch 42/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.4518 - loss: 0.4518 - val_binary_crossentropy: 0.4555 - val_loss: 0.4555
# Epoch 43/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.4562 - loss: 0.4562 - val_binary_crossentropy: 0.4501 - val_loss: 0.4501
# Epoch 44/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.4600 - loss: 0.4600 - val_binary_crossentropy: 0.4448 - val_loss: 0.4448
# Epoch 45/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.4490 - loss: 0.4490 - val_binary_crossentropy: 0.4393 - val_loss: 0.4393
# Epoch 46/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.4236 - loss: 0.4236 - val_binary_crossentropy: 0.4341 - val_loss: 0.4341
# Epoch 47/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.4542 - loss: 0.4542 - val_binary_crossentropy: 0.4288 - val_loss: 0.4288
# Epoch 48/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.4340 - loss: 0.4340 - val_binary_crossentropy: 0.4237 - val_loss: 0.4237
# Epoch 49/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.4174 - loss: 0.4174 - val_binary_crossentropy: 0.4185 - val_loss: 0.4185
# Epoch 50/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.4128 - loss: 0.4128 - val_binary_crossentropy: 0.4134 - val_loss: 0.4134
# Epoch 51/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.4095 - loss: 0.4095 - val_binary_crossentropy: 0.4085 - val_loss: 0.4085
# Epoch 52/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.4116 - loss: 0.4116 - val_binary_crossentropy: 0.4036 - val_loss: 0.4036
# Epoch 53/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.3935 - loss: 0.3935 - val_binary_crossentropy: 0.3987 - val_loss: 0.3987
# Epoch 54/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3827 - loss: 0.3827 - val_binary_crossentropy: 0.3940 - val_loss: 0.3940
# Epoch 55/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.3912 - loss: 0.3912 - val_binary_crossentropy: 0.3892 - val_loss: 0.3892
# Epoch 56/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.3819 - loss: 0.3819 - val_binary_crossentropy: 0.3847 - val_loss: 0.3847
# Epoch 57/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3881 - loss: 0.3881 - val_binary_crossentropy: 0.3801 - val_loss: 0.3801
# Epoch 58/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.3735 - loss: 0.3735 - val_binary_crossentropy: 0.3757 - val_loss: 0.3757
# Epoch 59/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.3735 - loss: 0.3735 - val_binary_crossentropy: 0.3713 - val_loss: 0.3713
# Epoch 60/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3778 - loss: 0.3778 - val_binary_crossentropy: 0.3671 - val_loss: 0.3671
# Epoch 61/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3666 - loss: 0.3666 - val_binary_crossentropy: 0.3628 - val_loss: 0.3628
# Epoch 62/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3633 - loss: 0.3633 - val_binary_crossentropy: 0.3587 - val_loss: 0.3587
# Epoch 63/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3506 - loss: 0.3506 - val_binary_crossentropy: 0.3547 - val_loss: 0.3547
# Epoch 64/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.3490 - loss: 0.3490 - val_binary_crossentropy: 0.3507 - val_loss: 0.3507
# Epoch 65/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.3557 - loss: 0.3557 - val_binary_crossentropy: 0.3468 - val_loss: 0.3468
# Epoch 66/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3387 - loss: 0.3387 - val_binary_crossentropy: 0.3431 - val_loss: 0.3431
# Epoch 67/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3404 - loss: 0.3404 - val_binary_crossentropy: 0.3393 - val_loss: 0.3393
# Epoch 68/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3415 - loss: 0.3415 - val_binary_crossentropy: 0.3357 - val_loss: 0.3357
# Epoch 69/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3192 - loss: 0.3192 - val_binary_crossentropy: 0.3322 - val_loss: 0.3322
# Epoch 70/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3118 - loss: 0.3118 - val_binary_crossentropy: 0.3287 - val_loss: 0.3287
# Epoch 71/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3159 - loss: 0.3159 - val_binary_crossentropy: 0.3254 - val_loss: 0.3254
# Epoch 72/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.3133 - loss: 0.3133 - val_binary_crossentropy: 0.3220 - val_loss: 0.3220
# Epoch 73/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.3216 - loss: 0.3216 - val_binary_crossentropy: 0.3187 - val_loss: 0.3187
# Epoch 74/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3055 - loss: 0.3055 - val_binary_crossentropy: 0.3156 - val_loss: 0.3156
# Epoch 75/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.3134 - loss: 0.3134 - val_binary_crossentropy: 0.3125 - val_loss: 0.3125
# Epoch 76/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_crossentropy: 0.3065 - loss: 0.3065 - val_binary_crossentropy: 0.3093 - val_loss: 0.3093
# Epoch 77/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.2868 - loss: 0.2868 - val_binary_crossentropy: 0.3063 - val_loss: 0.3063
# Epoch 78/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.2856 - loss: 0.2856 - val_binary_crossentropy: 0.3035 - val_loss: 0.3035
# Epoch 79/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.2923 - loss: 0.2923 - val_binary_crossentropy: 0.3006 - val_loss: 0.3006
# Epoch 80/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.2995 - loss: 0.2995 - val_binary_crossentropy: 0.2979 - val_loss: 0.2979
# Epoch 81/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.3004 - loss: 0.3004 - val_binary_crossentropy: 0.2952 - val_loss: 0.2952
# Epoch 82/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2651 - loss: 0.2651 - val_binary_crossentropy: 0.2925 - val_loss: 0.2925
# Epoch 83/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2749 - loss: 0.2749 - val_binary_crossentropy: 0.2901 - val_loss: 0.2901
# Epoch 84/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2710 - loss: 0.2710 - val_binary_crossentropy: 0.2873 - val_loss: 0.2873
# Epoch 85/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2719 - loss: 0.2719 - val_binary_crossentropy: 0.2849 - val_loss: 0.2849
# Epoch 86/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2492 - loss: 0.2492 - val_binary_crossentropy: 0.2825 - val_loss: 0.2825
# Epoch 87/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2713 - loss: 0.2713 - val_binary_crossentropy: 0.2802 - val_loss: 0.2802
# Epoch 88/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2583 - loss: 0.2583 - val_binary_crossentropy: 0.2781 - val_loss: 0.2781
# Epoch 89/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2610 - loss: 0.2610 - val_binary_crossentropy: 0.2755 - val_loss: 0.2755
# Epoch 90/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2469 - loss: 0.2469 - val_binary_crossentropy: 0.2735 - val_loss: 0.2735
# Epoch 91/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.2587 - loss: 0.2587 - val_binary_crossentropy: 0.2715 - val_loss: 0.2715
# Epoch 92/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.2631 - loss: 0.2631 - val_binary_crossentropy: 0.2690 - val_loss: 0.2690
# Epoch 93/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.2617 - loss: 0.2617 - val_binary_crossentropy: 0.2669 - val_loss: 0.2669
# Epoch 94/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.2584 - loss: 0.2584 - val_binary_crossentropy: 0.2650 - val_loss: 0.2650
# Epoch 95/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.2617 - loss: 0.2617 - val_binary_crossentropy: 0.2630 - val_loss: 0.2630
# Epoch 96/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.2440 - loss: 0.2440 - val_binary_crossentropy: 0.2610 - val_loss: 0.2610
# Epoch 97/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.2200 - loss: 0.2200 - val_binary_crossentropy: 0.2591 - val_loss: 0.2591
# Epoch 98/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2447 - loss: 0.2447 - val_binary_crossentropy: 0.2574 - val_loss: 0.2574
# Epoch 99/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2544 - loss: 0.2544 - val_binary_crossentropy: 0.2554 - val_loss: 0.2554
# Epoch 100/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2444 - loss: 0.2444 - val_binary_crossentropy: 0.2537 - val_loss: 0.2537

# %% [markdown]
# # Evaluation

# %%
y_pre = model.predict(X_test)
confusion_matrix(np.argmax(y_pre, axis=1), np.argmax(y_test, axis = 1))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# array([[ 57,   3],
#        [  7, 104]])

# %% [markdown]
# # RBF Neural Netrowk Training

# %%
model = Sequential()
model.add(RBFLayer(50, 0.15, name = 'RBF', trainable = True))
model.add(keras.layers.Dense(2, activation = 'sigmoid'))
opt = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer = opt, loss=loss, metrics = ['binary_crossentropy'])
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 200, batch_size = 5)
# Out:
# Epoch 1/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_crossentropy: 0.6166 - loss: 0.6166 - val_binary_crossentropy: 0.5691 - val_loss: 0.5691
# Epoch 2/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.5980 - loss: 0.5980 - val_binary_crossentropy: 0.5275 - val_loss: 0.5275
# Epoch 3/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.5719 - loss: 0.5719 - val_binary_crossentropy: 0.4988 - val_loss: 0.4988
# Epoch 4/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.5430 - loss: 0.5430 - val_binary_crossentropy: 0.4720 - val_loss: 0.4720
# Epoch 5/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.4750 - loss: 0.4750 - val_binary_crossentropy: 0.4496 - val_loss: 0.4496
# Epoch 6/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.4316 - loss: 0.4316 - val_binary_crossentropy: 0.4470 - val_loss: 0.4470
# Epoch 7/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.4535 - loss: 0.4535 - val_binary_crossentropy: 0.4000 - val_loss: 0.4000
# Epoch 8/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.4139 - loss: 0.4139 - val_binary_crossentropy: 0.3779 - val_loss: 0.3779
# Epoch 9/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.3760 - loss: 0.3760 - val_binary_crossentropy: 0.3587 - val_loss: 0.3587
# Epoch 10/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.3745 - loss: 0.3745 - val_binary_crossentropy: 0.3440 - val_loss: 0.3440
# Epoch 11/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.3447 - loss: 0.3447 - val_binary_crossentropy: 0.3193 - val_loss: 0.3193
# Epoch 12/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.3244 - loss: 0.3244 - val_binary_crossentropy: 0.3068 - val_loss: 0.3068
# Epoch 13/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.2896 - loss: 0.2896 - val_binary_crossentropy: 0.2835 - val_loss: 0.2835
# Epoch 14/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.2794 - loss: 0.2794 - val_binary_crossentropy: 0.2827 - val_loss: 0.2827
# Epoch 15/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.2859 - loss: 0.2859 - val_binary_crossentropy: 0.2548 - val_loss: 0.2548
# Epoch 16/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.2563 - loss: 0.2563 - val_binary_crossentropy: 0.2477 - val_loss: 0.2477
# Epoch 17/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.2631 - loss: 0.2631 - val_binary_crossentropy: 0.2387 - val_loss: 0.2387
# Epoch 18/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2563 - loss: 0.2563 - val_binary_crossentropy: 0.2223 - val_loss: 0.2223
# Epoch 19/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_crossentropy: 0.2259 - loss: 0.2259 - val_binary_crossentropy: 0.2125 - val_loss: 0.2125
# Epoch 20/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.2016 - loss: 0.2016 - val_binary_crossentropy: 0.2044 - val_loss: 0.2044
# Epoch 21/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.1942 - loss: 0.1942 - val_binary_crossentropy: 0.1991 - val_loss: 0.1991
# Epoch 22/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1848 - loss: 0.1848 - val_binary_crossentropy: 0.1908 - val_loss: 0.1908
# Epoch 23/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.2228 - loss: 0.2228 - val_binary_crossentropy: 0.1875 - val_loss: 0.1875
# Epoch 24/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1647 - loss: 0.1647 - val_binary_crossentropy: 0.1803 - val_loss: 0.1803
# Epoch 25/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1619 - loss: 0.1619 - val_binary_crossentropy: 0.1767 - val_loss: 0.1767
# Epoch 26/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.1878 - loss: 0.1878 - val_binary_crossentropy: 0.1722 - val_loss: 0.1722
# Epoch 27/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.2000 - loss: 0.2000 - val_binary_crossentropy: 0.1737 - val_loss: 0.1737
# Epoch 28/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.1802 - loss: 0.1802 - val_binary_crossentropy: 0.1646 - val_loss: 0.1646
# Epoch 29/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1748 - loss: 0.1748 - val_binary_crossentropy: 0.1602 - val_loss: 0.1602
# Epoch 30/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1528 - loss: 0.1528 - val_binary_crossentropy: 0.1578 - val_loss: 0.1578
# Epoch 31/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.1577 - loss: 0.1577 - val_binary_crossentropy: 0.1543 - val_loss: 0.1543
# Epoch 32/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1733 - loss: 0.1733 - val_binary_crossentropy: 0.1516 - val_loss: 0.1516
# Epoch 33/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1529 - loss: 0.1529 - val_binary_crossentropy: 0.1492 - val_loss: 0.1492
# Epoch 34/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1223 - loss: 0.1223 - val_binary_crossentropy: 0.1490 - val_loss: 0.1490
# Epoch 35/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1452 - loss: 0.1452 - val_binary_crossentropy: 0.1478 - val_loss: 0.1478
# Epoch 36/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1195 - loss: 0.1195 - val_binary_crossentropy: 0.1465 - val_loss: 0.1465
# Epoch 37/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1213 - loss: 0.1213 - val_binary_crossentropy: 0.1410 - val_loss: 0.1410
# Epoch 38/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1576 - loss: 0.1576 - val_binary_crossentropy: 0.1400 - val_loss: 0.1400
# Epoch 39/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1182 - loss: 0.1182 - val_binary_crossentropy: 0.1376 - val_loss: 0.1376
# Epoch 40/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1137 - loss: 0.1137 - val_binary_crossentropy: 0.1362 - val_loss: 0.1362
# Epoch 41/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1302 - loss: 0.1302 - val_binary_crossentropy: 0.1346 - val_loss: 0.1346
# Epoch 42/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.1007 - loss: 0.1007 - val_binary_crossentropy: 0.1351 - val_loss: 0.1351
# Epoch 43/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1277 - loss: 0.1277 - val_binary_crossentropy: 0.1377 - val_loss: 0.1377
# Epoch 44/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.1305 - loss: 0.1305 - val_binary_crossentropy: 0.1305 - val_loss: 0.1305
# Epoch 45/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1488 - loss: 0.1488 - val_binary_crossentropy: 0.1352 - val_loss: 0.1352
# Epoch 46/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1042 - loss: 0.1042 - val_binary_crossentropy: 0.1303 - val_loss: 0.1303
# Epoch 47/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1135 - loss: 0.1135 - val_binary_crossentropy: 0.1273 - val_loss: 0.1273
# Epoch 48/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1211 - loss: 0.1211 - val_binary_crossentropy: 0.1263 - val_loss: 0.1263
# Epoch 49/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.1169 - loss: 0.1169 - val_binary_crossentropy: 0.1283 - val_loss: 0.1283
# Epoch 50/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.1046 - loss: 0.1046 - val_binary_crossentropy: 0.1248 - val_loss: 0.1248
# Epoch 51/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.1046 - loss: 0.1046 - val_binary_crossentropy: 0.1238 - val_loss: 0.1238
# Epoch 52/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.1035 - loss: 0.1035 - val_binary_crossentropy: 0.1226 - val_loss: 0.1226
# Epoch 53/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1101 - loss: 0.1101 - val_binary_crossentropy: 0.1226 - val_loss: 0.1226
# Epoch 54/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1008 - loss: 0.1008 - val_binary_crossentropy: 0.1230 - val_loss: 0.1230
# Epoch 55/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0924 - loss: 0.0924 - val_binary_crossentropy: 0.1204 - val_loss: 0.1204
# Epoch 56/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1047 - loss: 0.1047 - val_binary_crossentropy: 0.1210 - val_loss: 0.1210
# Epoch 57/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0946 - loss: 0.0946 - val_binary_crossentropy: 0.1208 - val_loss: 0.1208
# Epoch 58/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1117 - loss: 0.1117 - val_binary_crossentropy: 0.1184 - val_loss: 0.1184
# Epoch 59/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1035 - loss: 0.1035 - val_binary_crossentropy: 0.1182 - val_loss: 0.1182
# Epoch 60/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0837 - loss: 0.0837 - val_binary_crossentropy: 0.1178 - val_loss: 0.1178
# Epoch 61/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0838 - loss: 0.0838 - val_binary_crossentropy: 0.1171 - val_loss: 0.1171
# Epoch 62/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1024 - loss: 0.1024 - val_binary_crossentropy: 0.1162 - val_loss: 0.1162
# Epoch 63/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0926 - loss: 0.0926 - val_binary_crossentropy: 0.1156 - val_loss: 0.1156
# Epoch 64/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.1308 - loss: 0.1308 - val_binary_crossentropy: 0.1153 - val_loss: 0.1153
# Epoch 65/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.1076 - loss: 0.1076 - val_binary_crossentropy: 0.1157 - val_loss: 0.1157
# Epoch 66/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1031 - loss: 0.1031 - val_binary_crossentropy: 0.1148 - val_loss: 0.1148
# Epoch 67/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0999 - loss: 0.0999 - val_binary_crossentropy: 0.1137 - val_loss: 0.1137
# Epoch 68/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0945 - loss: 0.0945 - val_binary_crossentropy: 0.1143 - val_loss: 0.1143
# Epoch 69/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0874 - loss: 0.0874 - val_binary_crossentropy: 0.1147 - val_loss: 0.1147
# Epoch 70/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0830 - loss: 0.0830 - val_binary_crossentropy: 0.1126 - val_loss: 0.1126
# Epoch 71/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0845 - loss: 0.0845 - val_binary_crossentropy: 0.1201 - val_loss: 0.1201
# Epoch 72/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0942 - loss: 0.0942 - val_binary_crossentropy: 0.1119 - val_loss: 0.1119
# Epoch 73/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0925 - loss: 0.0925 - val_binary_crossentropy: 0.1115 - val_loss: 0.1115
# Epoch 74/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0963 - loss: 0.0963 - val_binary_crossentropy: 0.1164 - val_loss: 0.1164
# Epoch 75/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0961 - loss: 0.0961 - val_binary_crossentropy: 0.1108 - val_loss: 0.1108
# Epoch 76/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1062 - loss: 0.1062 - val_binary_crossentropy: 0.1103 - val_loss: 0.1103
# Epoch 77/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0999 - loss: 0.0999 - val_binary_crossentropy: 0.1099 - val_loss: 0.1099
# Epoch 78/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0907 - loss: 0.0907 - val_binary_crossentropy: 0.1099 - val_loss: 0.1099
# Epoch 79/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_crossentropy: 0.0856 - loss: 0.0856 - val_binary_crossentropy: 0.1108 - val_loss: 0.1108
# Epoch 80/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.0837 - loss: 0.0837 - val_binary_crossentropy: 0.1112 - val_loss: 0.1112
# Epoch 81/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.0893 - loss: 0.0893 - val_binary_crossentropy: 0.1097 - val_loss: 0.1097
# Epoch 82/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0693 - loss: 0.0693 - val_binary_crossentropy: 0.1129 - val_loss: 0.1129
# Epoch 83/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1011 - loss: 0.1011 - val_binary_crossentropy: 0.1097 - val_loss: 0.1097
# Epoch 84/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0812 - loss: 0.0812 - val_binary_crossentropy: 0.1085 - val_loss: 0.1085
# Epoch 85/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0965 - loss: 0.0965 - val_binary_crossentropy: 0.1096 - val_loss: 0.1096
# Epoch 86/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0741 - loss: 0.0741 - val_binary_crossentropy: 0.1092 - val_loss: 0.1092
# Epoch 87/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0926 - loss: 0.0926 - val_binary_crossentropy: 0.1072 - val_loss: 0.1072
# Epoch 88/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0655 - loss: 0.0655 - val_binary_crossentropy: 0.1074 - val_loss: 0.1074
# Epoch 89/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0974 - loss: 0.0974 - val_binary_crossentropy: 0.1069 - val_loss: 0.1069
# Epoch 90/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0720 - loss: 0.0720 - val_binary_crossentropy: 0.1068 - val_loss: 0.1068
# Epoch 91/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0884 - loss: 0.0884 - val_binary_crossentropy: 0.1111 - val_loss: 0.1111
# Epoch 92/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0610 - loss: 0.0610 - val_binary_crossentropy: 0.1078 - val_loss: 0.1078
# Epoch 93/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0994 - loss: 0.0994 - val_binary_crossentropy: 0.1057 - val_loss: 0.1057
# Epoch 94/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1033 - loss: 0.1033 - val_binary_crossentropy: 0.1067 - val_loss: 0.1067
# Epoch 95/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0730 - loss: 0.0730 - val_binary_crossentropy: 0.1074 - val_loss: 0.1074
# Epoch 96/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0737 - loss: 0.0737 - val_binary_crossentropy: 0.1081 - val_loss: 0.1081
# Epoch 97/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0796 - loss: 0.0796 - val_binary_crossentropy: 0.1057 - val_loss: 0.1057
# Epoch 98/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0831 - loss: 0.0831 - val_binary_crossentropy: 0.1057 - val_loss: 0.1057
# Epoch 99/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0819 - loss: 0.0819 - val_binary_crossentropy: 0.1047 - val_loss: 0.1047
# Epoch 100/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0907 - loss: 0.0907 - val_binary_crossentropy: 0.1045 - val_loss: 0.1045
# Epoch 101/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0674 - loss: 0.0674 - val_binary_crossentropy: 0.1087 - val_loss: 0.1087
# Epoch 102/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.1001 - loss: 0.1001 - val_binary_crossentropy: 0.1050 - val_loss: 0.1050
# Epoch 103/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0666 - loss: 0.0666 - val_binary_crossentropy: 0.1055 - val_loss: 0.1055
# Epoch 104/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.1000 - loss: 0.1000 - val_binary_crossentropy: 0.1037 - val_loss: 0.1037
# Epoch 105/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0772 - loss: 0.0772 - val_binary_crossentropy: 0.1037 - val_loss: 0.1037
# Epoch 106/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0723 - loss: 0.0723 - val_binary_crossentropy: 0.1064 - val_loss: 0.1064
# Epoch 107/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0770 - loss: 0.0770 - val_binary_crossentropy: 0.1032 - val_loss: 0.1032
# Epoch 108/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.0787 - loss: 0.0787 - val_binary_crossentropy: 0.1055 - val_loss: 0.1055
# Epoch 109/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0859 - loss: 0.0859 - val_binary_crossentropy: 0.1029 - val_loss: 0.1029
# Epoch 110/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0983 - loss: 0.0983 - val_binary_crossentropy: 0.1027 - val_loss: 0.1027
# Epoch 111/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0808 - loss: 0.0808 - val_binary_crossentropy: 0.1030 - val_loss: 0.1030
# Epoch 112/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0860 - loss: 0.0860 - val_binary_crossentropy: 0.1043 - val_loss: 0.1043
# Epoch 113/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0927 - loss: 0.0927 - val_binary_crossentropy: 0.1024 - val_loss: 0.1024
# Epoch 114/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1007 - loss: 0.1007 - val_binary_crossentropy: 0.1021 - val_loss: 0.1021
# Epoch 115/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0889 - loss: 0.0889 - val_binary_crossentropy: 0.1021 - val_loss: 0.1021
# Epoch 116/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0553 - loss: 0.0553 - val_binary_crossentropy: 0.1019 - val_loss: 0.1019
# Epoch 117/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1033 - loss: 0.1033 - val_binary_crossentropy: 0.1016 - val_loss: 0.1016
# Epoch 118/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0785 - loss: 0.0785 - val_binary_crossentropy: 0.1017 - val_loss: 0.1017
# Epoch 119/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0803 - loss: 0.0803 - val_binary_crossentropy: 0.1043 - val_loss: 0.1043
# Epoch 120/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0787 - loss: 0.0787 - val_binary_crossentropy: 0.1013 - val_loss: 0.1013
# Epoch 121/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0862 - loss: 0.0862 - val_binary_crossentropy: 0.1013 - val_loss: 0.1013
# Epoch 122/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0786 - loss: 0.0786 - val_binary_crossentropy: 0.1010 - val_loss: 0.1010
# Epoch 123/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.1222 - loss: 0.1222 - val_binary_crossentropy: 0.1010 - val_loss: 0.1010
# Epoch 124/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0894 - loss: 0.0894 - val_binary_crossentropy: 0.1029 - val_loss: 0.1029
# Epoch 125/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0753 - loss: 0.0753 - val_binary_crossentropy: 0.1008 - val_loss: 0.1008
# Epoch 126/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0667 - loss: 0.0667 - val_binary_crossentropy: 0.1010 - val_loss: 0.1010
# Epoch 127/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0653 - loss: 0.0653 - val_binary_crossentropy: 0.1041 - val_loss: 0.1041
# Epoch 128/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0864 - loss: 0.0864 - val_binary_crossentropy: 0.1019 - val_loss: 0.1019
# Epoch 129/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0801 - loss: 0.0801 - val_binary_crossentropy: 0.1003 - val_loss: 0.1003
# Epoch 130/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0785 - loss: 0.0785 - val_binary_crossentropy: 0.1011 - val_loss: 0.1011
# Epoch 131/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0616 - loss: 0.0616 - val_binary_crossentropy: 0.1015 - val_loss: 0.1015
# Epoch 132/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0957 - loss: 0.0957 - val_binary_crossentropy: 0.1011 - val_loss: 0.1011
# Epoch 133/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0671 - loss: 0.0671 - val_binary_crossentropy: 0.1016 - val_loss: 0.1016
# Epoch 134/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0595 - loss: 0.0595 - val_binary_crossentropy: 0.0996 - val_loss: 0.0996
# Epoch 135/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0890 - loss: 0.0890 - val_binary_crossentropy: 0.0995 - val_loss: 0.0995
# Epoch 136/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0711 - loss: 0.0711 - val_binary_crossentropy: 0.1003 - val_loss: 0.1003
# Epoch 137/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0522 - loss: 0.0522 - val_binary_crossentropy: 0.1016 - val_loss: 0.1016
# Epoch 138/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.0847 - loss: 0.0847 - val_binary_crossentropy: 0.0992 - val_loss: 0.0992
# Epoch 139/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_crossentropy: 0.0619 - loss: 0.0619 - val_binary_crossentropy: 0.1016 - val_loss: 0.1016
# Epoch 140/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0862 - loss: 0.0862 - val_binary_crossentropy: 0.1001 - val_loss: 0.1001
# Epoch 141/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0712 - loss: 0.0712 - val_binary_crossentropy: 0.0998 - val_loss: 0.0998
# Epoch 142/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0834 - loss: 0.0834 - val_binary_crossentropy: 0.1031 - val_loss: 0.1031
# Epoch 143/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0806 - loss: 0.0806 - val_binary_crossentropy: 0.1002 - val_loss: 0.1002
# Epoch 144/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0856 - loss: 0.0856 - val_binary_crossentropy: 0.1004 - val_loss: 0.1004
# Epoch 145/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0708 - loss: 0.0708 - val_binary_crossentropy: 0.0995 - val_loss: 0.0995
# Epoch 146/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0769 - loss: 0.0769 - val_binary_crossentropy: 0.0984 - val_loss: 0.0984
# Epoch 147/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0767 - loss: 0.0767 - val_binary_crossentropy: 0.0984 - val_loss: 0.0984
# Epoch 148/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0824 - loss: 0.0824 - val_binary_crossentropy: 0.0987 - val_loss: 0.0987
# Epoch 149/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0920 - loss: 0.0920 - val_binary_crossentropy: 0.0984 - val_loss: 0.0984
# Epoch 150/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0700 - loss: 0.0700 - val_binary_crossentropy: 0.0981 - val_loss: 0.0981
# Epoch 151/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0650 - loss: 0.0650 - val_binary_crossentropy: 0.1019 - val_loss: 0.1019
# Epoch 152/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0659 - loss: 0.0659 - val_binary_crossentropy: 0.0984 - val_loss: 0.0984
# Epoch 153/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0593 - loss: 0.0593 - val_binary_crossentropy: 0.1008 - val_loss: 0.1008
# Epoch 154/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0602 - loss: 0.0602 - val_binary_crossentropy: 0.0980 - val_loss: 0.0980
# Epoch 155/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0888 - loss: 0.0888 - val_binary_crossentropy: 0.1025 - val_loss: 0.1025
# Epoch 156/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0637 - loss: 0.0637 - val_binary_crossentropy: 0.0990 - val_loss: 0.0990
# Epoch 157/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0871 - loss: 0.0871 - val_binary_crossentropy: 0.0978 - val_loss: 0.0978
# Epoch 158/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0657 - loss: 0.0657 - val_binary_crossentropy: 0.0974 - val_loss: 0.0974
# Epoch 159/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0667 - loss: 0.0667 - val_binary_crossentropy: 0.0981 - val_loss: 0.0981
# Epoch 160/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0651 - loss: 0.0651 - val_binary_crossentropy: 0.1001 - val_loss: 0.1001
# Epoch 161/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0657 - loss: 0.0657 - val_binary_crossentropy: 0.0992 - val_loss: 0.0992
# Epoch 162/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0709 - loss: 0.0709 - val_binary_crossentropy: 0.0979 - val_loss: 0.0979
# Epoch 163/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0689 - loss: 0.0689 - val_binary_crossentropy: 0.0976 - val_loss: 0.0976
# Epoch 164/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0543 - loss: 0.0543 - val_binary_crossentropy: 0.0969 - val_loss: 0.0969
# Epoch 165/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0722 - loss: 0.0722 - val_binary_crossentropy: 0.0968 - val_loss: 0.0968
# Epoch 166/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0990 - loss: 0.0990 - val_binary_crossentropy: 0.0967 - val_loss: 0.0967
# Epoch 167/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.0770 - loss: 0.0770 - val_binary_crossentropy: 0.0974 - val_loss: 0.0974
# Epoch 168/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.0764 - loss: 0.0764 - val_binary_crossentropy: 0.0978 - val_loss: 0.0978
# Epoch 169/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_crossentropy: 0.0688 - loss: 0.0688 - val_binary_crossentropy: 0.0971 - val_loss: 0.0971
# Epoch 170/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0562 - loss: 0.0562 - val_binary_crossentropy: 0.0976 - val_loss: 0.0976
# Epoch 171/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0732 - loss: 0.0732 - val_binary_crossentropy: 0.0994 - val_loss: 0.0994
# Epoch 172/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0647 - loss: 0.0647 - val_binary_crossentropy: 0.0963 - val_loss: 0.0963
# Epoch 173/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0851 - loss: 0.0851 - val_binary_crossentropy: 0.0980 - val_loss: 0.0980
# Epoch 174/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0726 - loss: 0.0726 - val_binary_crossentropy: 0.0986 - val_loss: 0.0986
# Epoch 175/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0531 - loss: 0.0531 - val_binary_crossentropy: 0.1038 - val_loss: 0.1038
# Epoch 176/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0876 - loss: 0.0876 - val_binary_crossentropy: 0.0966 - val_loss: 0.0966
# Epoch 177/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0824 - loss: 0.0824 - val_binary_crossentropy: 0.0961 - val_loss: 0.0961
# Epoch 178/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0591 - loss: 0.0591 - val_binary_crossentropy: 0.0974 - val_loss: 0.0974
# Epoch 179/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0730 - loss: 0.0730 - val_binary_crossentropy: 0.0976 - val_loss: 0.0976
# Epoch 180/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0596 - loss: 0.0596 - val_binary_crossentropy: 0.1024 - val_loss: 0.1024
# Epoch 181/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0805 - loss: 0.0805 - val_binary_crossentropy: 0.0962 - val_loss: 0.0962
# Epoch 182/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0708 - loss: 0.0708 - val_binary_crossentropy: 0.0956 - val_loss: 0.0956
# Epoch 183/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0790 - loss: 0.0790 - val_binary_crossentropy: 0.0978 - val_loss: 0.0978
# Epoch 184/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0793 - loss: 0.0793 - val_binary_crossentropy: 0.0958 - val_loss: 0.0958
# Epoch 185/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0740 - loss: 0.0740 - val_binary_crossentropy: 0.0978 - val_loss: 0.0978
# Epoch 186/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0586 - loss: 0.0586 - val_binary_crossentropy: 0.1003 - val_loss: 0.1003
# Epoch 187/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0525 - loss: 0.0525 - val_binary_crossentropy: 0.0974 - val_loss: 0.0974
# Epoch 188/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0650 - loss: 0.0650 - val_binary_crossentropy: 0.1017 - val_loss: 0.1017
# Epoch 189/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0606 - loss: 0.0606 - val_binary_crossentropy: 0.0953 - val_loss: 0.0953
# Epoch 190/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_crossentropy: 0.0744 - loss: 0.0744 - val_binary_crossentropy: 0.0952 - val_loss: 0.0952
# Epoch 191/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0890 - loss: 0.0890 - val_binary_crossentropy: 0.0970 - val_loss: 0.0970
# Epoch 192/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0664 - loss: 0.0664 - val_binary_crossentropy: 0.0975 - val_loss: 0.0975
# Epoch 193/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0623 - loss: 0.0623 - val_binary_crossentropy: 0.0965 - val_loss: 0.0965
# Epoch 194/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_crossentropy: 0.0545 - loss: 0.0545 - val_binary_crossentropy: 0.0964 - val_loss: 0.0964
# Epoch 195/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_crossentropy: 0.0596 - loss: 0.0596 - val_binary_crossentropy: 0.0982 - val_loss: 0.0982
# Epoch 196/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.0612 - loss: 0.0612 - val_binary_crossentropy: 0.0963 - val_loss: 0.0963
# Epoch 197/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_crossentropy: 0.0602 - loss: 0.0602 - val_binary_crossentropy: 0.0954 - val_loss: 0.0954
# Epoch 198/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_crossentropy: 0.0650 - loss: 0.0650 - val_binary_crossentropy: 0.0945 - val_loss: 0.0945
# Epoch 199/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0574 - loss: 0.0574 - val_binary_crossentropy: 0.1006 - val_loss: 0.1006
# Epoch 200/200
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_crossentropy: 0.0671 - loss: 0.0671 - val_binary_crossentropy: 0.0951 - val_loss: 0.0951

# %% [markdown]
# # Evaluation

# %%
y_pre = model.predict(X_test)
confusion_matrix(np.argmax(y_pre, axis=1), np.argmax(y_test, axis = 1))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# array([[ 57,   3],
#        [  3, 108]])
